# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys 
from datetime import datetime
import pandas as pd
import time
import re
import openpyxl
import pandas as pd
import requests
from bs4 import BeautifulSoup
import pickle

# %%
urldata = pd.read_pickle('mbti_게시글_url')
urllist = urldata['url'].tolist()

# %%
name_list = list()
mbti_list = list()
gender_list = list()
datetime_list = list()
text_list = list()
url_list = list()

# %%
for i in range(0,27500):
    page = requests.get(urllist[i])
    html = page.text
    soup = BeautifulSoup(html, 'html.parser')
    
    try:
        num_page = int(re.findall('[0-9]+', soup.select('span > a')[0].text)[1])
    except:
        num_page = 1

    for j in range(0,num_page):
        page = requests.get(urllist[i][:-5]+"-"+str(j+1)+".html")
        print(urllist[i][:-5]+"-"+str(j+1)+".html")
        html = page.text
        soup = BeautifulSoup(html, 'html.parser')

        userinfo = soup.select('div.postdetails > div.userinfo') # 유저 정보
        datetime = soup.select('div.posthead > span.postdate.old > span') # 날짜
        texts = soup.find_all('blockquote',{'class':'postcontent restore '}) # 본문
        
        for m in range(len(texts)): # 텍스트 처리 용  for 문
            try:
                texts[m].find('div',{'class':'bbcode_container'}).decompose()
            except:
                pass

            try:
                texts[m].find('div',{'class':'lockerdome'}).decompose()
            except:
                pass
            
            try:
                texts[m].find('a').decompose()
            except:
                pass
            
        
        for k in range(len(userinfo)):
            try:
                name_list.append(userinfo[k].text.strip().split("   ")[0])
            except:
                name_list.append("0")

            try:
                mbti_list.append(userinfo[k].text.strip().split("   ")[1])
            except:
                mbti_list.append("0")

            try:
                gender_list.append(userinfo[k].find('img')['src'].split('/')[-1].split('.')[0])
            except:
                gender_list.append("0")
            
            try:
                text_list.append(texts[k].get_text(strip=True))
            except:
                text_list.append("0")

            try:
                datetime_list.append(datetime[k].text)
            except:
                datetime_list.append("0")
                
            try:
                url_list.append(urllist[i][:-5]+"-"+str(j+1)+".html")
            except:
                url_list.append("0")
            
        print(j+1,"/",num_page)
    print(len(name_list),len(mbti_list),len(gender_list),len(text_list),len(datetime_list),len(url_list))
    print(i)
    
    if i % 1000 == 0:
        mbti_ls0 = [name_list,mbti_list,gender_list,text_list,datetime_list,url_list]
        mbti_ls = list(map(list,zip(*mbti_ls0)))
        mbti_df = pd.DataFrame(mbti_ls,columns =['name_list','mbti_list','gender_list','text_list','datetime_list','url_list'])

        mbti_df.to_csv('mbti_data'+str(i)+'.csv',index=False)   
        
        name_list = list()
        mbti_list = list()
        gender_list = list()
        datetime_list = list()
        text_list = list()
        url_list = list()
        
mbti_df.to_csv('mbti_data'+str(i)+'.csv',index=False)
# Out:
# https://www.personalitycafe.com/esfj-forum-caregivers/1302785-ask-esfj-question-1.html
# 1 / 6
# https://www.personalitycafe.com/esfj-forum-caregivers/1302785-ask-esfj-question-2.html
# 2 / 6
# https://www.personalitycafe.com/esfj-forum-caregivers/1302785-ask-esfj-question-3.html
# 3 / 6
# https://www.personalitycafe.com/esfj-forum-caregivers/1302785-ask-esfj-question-4.html
# 4 / 6
# https://www.personalitycafe.com/esfj-forum-caregivers/1302785-ask-esfj-question-5.html
# 5 / 6
lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~\Anaconda3\envs\tensorflow3.5\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~\Anaconda3\envs\tensorflow3.5\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     516         }
#     517         send_kwargs.update(settings)
# --> 518         resp = self.send(prep, **send_kwargs)
#     519
#     520         return resp
#
# ~\Anaconda3\envs\tensorflow3.5\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     637
#     638         # Send the request
# --> 639         r = adapter.send(request, **kwargs)
#     640
#     641         # Total elapsed time of the request (approximately)
#
# ~\Anaconda3\envs\tensorflow3.5\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     436                     decode_content=False,
#     437                     retries=self.max_retries,
# --> 438                     timeout=timeout
#     439                 )
#     440
#
# ~\Anaconda3\envs\tensorflow3.5\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~\Anaconda3\envs\tensorflow3.5\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#     381                 try:
# --> 382                     httplib_response = conn.getresponse()
#     383                 except Exception as e:
#     384                     # Remove the TypeError from the exception chain in Python 3;
#
# ~\Anaconda3\envs\tensorflow3.5\lib\http\client.py in getresponse(self)
#    1196         try:
#    1197             try:
# -> 1198                 response.begin()
#    1199             except ConnectionError:
#    1200                 self.close()
#
# ~\Anaconda3\envs\tensorflow3.5\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# ~\Anaconda3\envs\tensorflow3.5\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# ~\Anaconda3\envs\tensorflow3.5\lib\socket.py in readinto(self, b)
#     574         while True:
#     575             try:
# --> 576                 return self._sock.recv_into(b)
#     577             except timeout:
#     578                 self._timeout_occurred = True
#
# ~\Anaconda3\envs\tensorflow3.5\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#     935                   "non-zero flags not allowed in calls to recv_into() on %s" %
#     936                   self.__class__)
# --> 937             return self.read(nbytes, buffer)
#     938         else:
#     939             return socket.recv_into(self, buffer, nbytes, flags)
#
# ~\Anaconda3\envs\tensorflow3.5\lib\ssl.py in read(self, len, buffer)
#     797             raise ValueError("Read on closed or unwrapped SSL socket.")
#     798         try:
# --> 799             return self._sslobj.read(len, buffer)
#     800         except SSLError as x:
#     801             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# ~\Anaconda3\envs\tensorflow3.5\lib\ssl.py in read(self, len, buffer)
#     581         """
#     582         if buffer is not None:
# --> 583             v = self._sslobj.read(len, buffer)
#     584         else:
#     585             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
mbti_ls0 = [name_list,mbti_list,gender_list,text_list,datetime_list,url_list]
mbti_ls = list(map(list,zip(*mbti_ls0)))
mbti_df = pd.DataFrame(mbti_ls,columns =['name_list','mbti_list','gender_list','text_list','datetime_list','url_list'])

# %%
mbti_df
# Out:
#           name_list                   mbti_list gender_list  \
# 0         orion83uk                        ESFJ        Male
# 1           Happy29                        ESFJ      Female
# 2       SummerRoads                        ESFJ      Female
# 3           Happy29                        ESFJ      Female
# 4         orion83uk                        ESFJ        Male
# 5       SummerRoads                        ESFJ      Female
# 6             Sarge                     Unknown        Male
# 7       SummerRoads                        ESFJ      Female
# 8             Sarge                     Unknown        Male
# 9            Elwinz                     Unknown        Male
# 10            Sarge                     Unknown        Male
# 11        orion83uk                        ESFJ        Male
# 12            Sarge                     Unknown        Male
# 13       Civilkat92                           0           0
# 14            Echoe                     Unknown      Female
# 15        orion83uk                        ESFJ        Male
# 16      Santa Gloss                        INTP     Neutral
# 17        orion83uk                        ESFJ        Male
# 18            Echoe                     Unknown      Female
# 19        orion83uk                        ESFJ        Male
# 20          Happy29                        ESFJ      Female
# 21         Temizzle                        ENTJ        Male
# 22        orion83uk                        ESFJ        Male
# 23         Temizzle                        ENTJ        Male
# 24        orion83uk                        ESFJ        Male
# 25         Temizzle                        ENTJ        Male
# 26          Suntide                        ESFJ        Male
# 27             Sela  ISTJ - The Duty Fulfillers      Female
# 28          Suntide                        ESFJ        Male
# 29             Sela  ISTJ - The Duty Fulfillers      Female
# ..              ...                         ...         ...
# 683     NannyMercy4       ESFJ - The Caregivers      Female
# 684           Leroy        INFP - The Idealists        Male
# 685         nat2424        INFP - The Idealists      Female
# 686        vocalist       INFJ - The Protectors      Female
# 687         mmglory         INTP - The Thinkers      Female
# 688    Black Rabbit                        INFJ        Male
# 689         Korvyna                        ENFP      Female
