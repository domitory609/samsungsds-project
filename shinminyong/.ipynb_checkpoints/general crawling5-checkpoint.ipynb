# %%
from datetime import datetime
import pandas as pd
import time
import re
import openpyxl
import pandas as pd
import requests
from bs4 import BeautifulSoup
import pickle

# %%
urldata = pd.read_pickle('mbti_total_url.pkl')
urllist = urldata['url'].tolist()

# %%
len(urllist)
# Out:
# 49225

# %%
name_list = list()
gender_list = list()
datetime_list = list()
text_list = list()
url_list = list()

# %%
for i in range(40000,len(urllist)):
    page = requests.get(urllist[i])
    html = page.text
    soup = BeautifulSoup(html, 'html.parser')
    
    try:
        num_page = int(re.findall('[0-9]+', soup.select('span > a')[0].text)[1])
    except:
        num_page = 1

    for j in range(0,num_page):
        page = requests.get(urllist[i][:-5]+"-"+str(j+1)+".html")
        print(urllist[i][:-5]+"-"+str(j+1)+".html")
        html = page.text
        soup = BeautifulSoup(html, 'html.parser')

        userinfo = soup.select('div.postdetails > div.userinfo') # 유저 정보
        datetime = soup.select('div.posthead > span.postdate.old > span') # 날짜
        texts = soup.find_all('blockquote',{'class':'postcontent restore '}) # 본문  --dk만 띄어쓰기 없음('postcontent restore')
        
        for m in range(len(texts)): # 텍스트 처리 용  for 문
            try:
                texts[m].find('div',{'class':'bbcode_container'}).decompose()
            except:
                pass

            try:
                texts[m].find('div',{'class':'lockerdome'}).decompose()
            except:
                pass
            
            # site link 처리 보류
#             try:
#                 texts[m].find('a').decompose()
#             except:
#                 pass
            
        
        for k in range(len(userinfo)):
            try:
                name_list.append(userinfo[k].find('a',{'rel':'nofollow'}).text) 
            except:
                name_list.append("0")

            try:
                gender_list.append(userinfo[k].find('img')['src'].split('/')[-1].split('.')[0])
            except:
                gender_list.append("0")
            
            try:
                text_list.append(texts[k].get_text(strip=True))
            except:
                text_list.append("0")

            try:
                datetime_list.append(datetime[k].text)
            except:
                datetime_list.append("0")
                
            try:
                url_list.append(urllist[i][:-5]+"-"+str(j+1)+".html")
            except:
                url_list.append("0")
            
        print(j+1,"/",num_page)
    print(len(name_list),len(gender_list),len(text_list),len(datetime_list),len(url_list))
    print(i)
    
    
    if i % 10 == 0:
        mbti_ls0 = [name_list,gender_list,text_list,datetime_list,url_list]
        mbti_ls = list(map(list,zip(*mbti_ls0)))
        mbti_df = pd.DataFrame(mbti_ls,columns =['name_list','gender_list','text_list','datetime_list','url_list'])

        mbti_df.to_csv('./general_df/mbti_general_data'+str(i)+'.csv',index=False)   
        
        name_list = list()
        gender_list = list()
        datetime_list = list()
        text_list = list()
        url_list = list()

mbti_ls0 = [name_list,gender_list,text_list,datetime_list,url_list]
mbti_ls = list(map(list,zip(*mbti_ls0)))
mbti_df = pd.DataFrame(mbti_ls,columns =['name_list','gender_list','text_list','datetime_list','url_list'])

# https://www.personalitycafe.com/cognitive-functions/602018-p-e-t-type-profile-psychological-types-3.html
# 3 / 4
# https://www.personalitycafe.com/cognitive-functions/602018-p-e-t-type-profile-psychological-types-4.html
# 4 / 4
# 171 171 171 171 171
# 40009
# https://www.personalitycafe.com/cognitive-functions/645146-ne-si-ni-se-made-simple-1.html
# 1 / 1
# 177 177 177 177 177
# 40010
# https://www.personalitycafe.com/cognitive-functions/646154-introverted-intuition-porn-1.html
# 1 / 1
# 1 1 1 1 1
# 40011
# https://www.personalitycafe.com/cognitive-functions/645306-organised-thoughts-1.html
# 1 / 1
# 6 6 6 6 6
# 40012
# https://www.personalitycafe.com/cognitive-functions/634122-what-divergent-convergent-thinking-actually-related-ne-ni-1.html
# 1 / 3
# https://www.personalitycafe.com/cognitive-functions/634122-what-divergent-convergent-thinking-actually-related-ne-ni-2.html
# 2 / 3
# https://www.personalitycafe.com/cognitive-functions/634122-what-divergent-convergent-thinking-actually-related-ne-ni-3.html
# 3 / 3
# 35 35 35 35 35
# 40013
# https://www.personalitycafe.com/cognitive-functions/638066-strong-se-augmenting-weaker-te-ti-1.html
# 1 / 4
# https://www.personalitycafe.com/cognitive-functions/638066-strong-se-augmenting-weaker-te-ti-2.html
# 2 / 4
# https://www.personalitycafe.com/cognitive-functions/638066-strong-se-augmenting-weaker-te-ti-3.html
# 3 / 4
# https://www.personalitycafe.com/cognitive-functions/638066-strong-se-augmenting-weaker-te-ti-4.html
# 4 / 4
# 71 71 71 71 71
# 40014
# https://www.personalitycafe.com/cognitive-functions/642858-having-enormous-struggle-trying-understand-ni-si-help-please-1.html
# 1 / 3
# https://www.personalitycafe.com/cognitive-functions/642858-having-enormous-struggle-trying-understand-ni-si-help-please-2.html
# 2 / 3
# https://www.personalitycafe.com/cognitive-functions/642858-having-enormous-struggle-trying-understand-ni-si-help-please-3.html
# 3 / 3
# 103 103 103 103 103
# 40015
# https://www.personalitycafe.com/cognitive-functions/644394-what-cognitive-function-working-case-below-1.html
# 1 / 1
# 104 104 104 104 104
# 40016
# https://www.personalitycafe.com/cognitive-functions/639186-cognitive-functions-4-letter-code-1.html
# 1 / 4
# https://www.personalitycafe.com/cognitive-functions/639186-cognitive-functions-4-letter-code-2.html
# 2 / 4
# https://www.personalitycafe.com/cognitive-functions/639186-cognitive-functions-4-letter-code-3.html
# 3 / 4
# https://www.personalitycafe.com/cognitive-functions/639186-cognitive-functions-4-letter-code-4.html
# 4 / 4
# 140 140 140 140 140
# 40017
# https://www.personalitycafe.com/cognitive-functions/642377-ni-te-ne-ti-1.html
# 1 / 1
# 150 150 150 150 150
# 40018
